# %% [markdown]
# <a href="https://colab.research.google.com/github/shanakaChathu/Credit-Default-/blob/master/Tensorflow_Cousera.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def hw_function(x):
  y = (2 * x) - 1
  return y

hw_function(10)
# Out:
# 19

# %%
import tensorflow as tf
import numpy as np
from tensorflow import keras

# %%
model = tf.keras.Sequential([keras.layers.Dense(units=1, input_shape=[1])])
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/resource_variable_ops.py:435: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %%
model.compile(optimizer='sgd', loss='mean_squared_error')
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/utils/losses_utils.py:170: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.

# %%
xs = np.array([-1.0,  0.0, 1.0, 2.0, 3.0, 4.0], dtype=float)
ys = np.array([-3.0, -1.0, 1.0, 3.0, 5.0, 7.0], dtype=float)

# %%
model.fit(xs, ys, epochs=500)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Epoch 1/500
# 6/6 [==============================] - 1s 84ms/sample - loss: 4.3452
# Epoch 2/500
# 6/6 [==============================] - 0s 790us/sample - loss: 3.5876
# Epoch 3/500
# 6/6 [==============================] - 0s 650us/sample - loss: 2.9881
# Epoch 4/500
# 6/6 [==============================] - 0s 553us/sample - loss: 2.5130
# Epoch 5/500
# 6/6 [==============================] - 0s 644us/sample - loss: 2.1359
# Epoch 6/500
# 6/6 [==============================] - 0s 577us/sample - loss: 1.8359
# Epoch 7/500
# 6/6 [==============================] - 0s 573us/sample - loss: 1.5968
# Epoch 8/500
# 6/6 [==============================] - 0s 555us/sample - loss: 1.4055
# Epoch 9/500
# ...

# %%
print(model.predict([10.0]))
# Out:
# [[18.984596]]
